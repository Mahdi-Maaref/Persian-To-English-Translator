# %%
from huggingface_hub import HfApi, upload_folder #!pip install huggingface_hub

api = HfApi()

#  Api Token
HF_TOKEN = ""

# Destination Repo
REPO_ID = ""

# Model Path
MODEL_PATH = "/workspace/exports/ckptNava-Lite-0.6B_merged_16bit"

upload_folder(
    repo_id=REPO_ID,
    folder_path=MODEL_PATH,
    repo_type="model",
    token=HF_TOKEN,
)

print("✅ Upload finished!")
